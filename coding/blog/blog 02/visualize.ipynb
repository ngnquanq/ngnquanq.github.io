# %%
import numpy as np
import numpy as np
import numpy as np
import matplotlib.pyplot as plt

# Create the numpy array
arr = np.random.uniform(-0.003, 0.003, size=(150, 150))

# Set the figure size
plt.figure(figsize=(10, 8))

# Visualize the array using a heatmap
plt.imshow(arr, cmap='viridis', vmin=-0, vmax=1)
plt.colorbar()
plt.show()
